# %%
import pandas as pd
from textblob import TextBlob

# %%
listings = pd.read_csv('listings.csv')
listings = listings[["neighbourhood", "price"]]

# %%
listings = listings.groupby('neighbourhood').mean().reset_index()

# %%
_min = listings.price.min()
_max = listings.price.max()

listings.price = listings.price.apply(lambda x: ((x-_min)/(_max - _min)))
listings
# Out:
#                          neighbourhood     price
# 0                      Agincourt North  0.044287
# 1         Agincourt South-Malvern West  0.119123
# 2                            Alderwood  0.205009
# 3                                Annex  0.353881
# 4                    Banbury-Don Mills  0.236484
# 5                       Bathurst Manor  0.296362
# 6                  Bay Street Corridor  0.363107
# 7                      Bayview Village  0.183886
# 8                Bayview Woods-Steeles  0.075216
# 9                 Bedford Park-Nortown  0.464414
# 10             Beechborough-Greenbrook  0.207898
# 11                             Bendale  0.139638
# 12               Birchcliffe-Cliffside  0.311568
# 13                         Black Creek  0.046309
# 14                         Blake-Jones  0.243786
# 15                Briar Hill-Belgravia  0.033083
# 16   Bridle Path-Sunnybrook-York Mills  0.863702
# 17                     Broadview North  0.210357
# 18                 Brookhaven-Amesbury  0.069623
# 19     Cabbagetown-South St.James Town  0.256064
# 20                  Caledonia-Fairbank  0.038254
# 21                           Casa Loma  0.400462
# 22              Centennial Scarborough  0.074799
# 23               Church-Yonge Corridor  0.301018
# 24                 Clairlea-Birchmount  0.043091
# 25                        Clanton Park  0.980089
# 26                          Cliffcrest  0.477674
# 27              Corso Italia-Davenport  0.175360
# 28                            Danforth  0.194423
# 29                  Danforth East York  0.175938
# ..                                 ...       ...
# 109                    South Riverdale  0.336431
# 110               St.Andrew-Windfields  0.289663
# 111                            Steeles  0.006562
# 112                Stonegate-Queensway  0.297272
# 113             Tam O'Shanter-Sullivan  0.172005
# 114                      Taylor-Massey  0.027194
# 115                        The Beaches  0.538725
# 116       Thistletown-Beaumond Heights  0.035279
# 117                   Thorncliffe Park  0.117329
# 118                  Trinity-Bellwoods  0.334356
# 119                         University  0.338547
# 120                   Victoria Village  0.153736
# 121  Waterfront Communities-The Island  0.446085
# 122                          West Hill  0.106445
# 123             West Humber-Clairville  0.124786
# 124                Westminster-Branson  0.086004
# 125                             Weston  0.112397
# 126                 Weston-Pellam Park  0.105901
# 127                   Wexford/Maryvale  0.149816
# 128                    Willowdale East  0.192194
# 129                    Willowdale West  0.200860
# 130   Willowridge-Martingrove-Richview  0.049417
# 131                             Woburn  0.142325
# 132                  Woodbine Corridor  0.233515
# 133                   Woodbine-Lumsden  0.186957
# 134                           Wychwood  0.184714
# 135                     Yonge-Eglinton  0.369093
# 136                     Yonge-St.Clair  0.313606
# 137            York University Heights  0.030558
# 138                 Yorkdale-Glen Park  0.131539
#
# [139 rows x 2 columns]

# %%
import json
demo = {
    'result': listings.to_dict(orient='record')
}


with open('pricy.json', 'w') as outfile:
    json.dump(demo, outfile)
